# %%
import xarray as xr
# mount gdrive with this code
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
#below where the file is in gdrive, change with your
data_path = "/content/drive/My Drive/gfs.t12z.sfcf001.nc"
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
pip install cftime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.5 MB/s eta 0:00:00
# ...

# %%
# Open NetCDF file
ds = xr.open_dataset(data_path)

# %%
# Display dataset info
print(ds)
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:        (grid_xt: 3072, grid_yt: 1536, time: 1)
# Coordinates:
#   * grid_xt        (grid_xt) float64 25kB 0.0 0.1172 0.2344 ... 359.8 359.9
#   * grid_yt        (grid_yt) float64 12kB 89.91 89.79 89.68 ... -89.79 -89.91
#   * time           (time) object 8B 2021-03-24 13:00:00
# Data variables: (12/150)
#     lon            (grid_yt, grid_xt) float64 38MB ...
#     lat            (grid_yt, grid_xt) float64 38MB ...
#     acond          (time, grid_yt, grid_xt) float32 19MB ...
#     albdo_ave      (time, grid_yt, grid_xt) float32 19MB ...
#     alnsf          (time, grid_yt, grid_xt) float32 19MB ...
#     alnwf          (time, grid_yt, grid_xt) float32 19MB ...
#     ...             ...
#     xtts           (time, grid_yt, grid_xt) float32 19MB ...
#     xu             (time, grid_yt, grid_xt) float32 19MB ...
#     xv             (time, grid_yt, grid_xt) float32 19MB ...
#     xz             (time, grid_yt, grid_xt) float32 19MB ...
# ...

# %%
print(ds.variables)
# Out:
# Frozen({'grid_xt': <xarray.IndexVariable 'grid_xt' (grid_xt: 3072)> Size: 25kB
# array([0.000000e+00, 1.171875e-01, 2.343750e-01, ..., 3.596484e+02,
#        3.597656e+02, 3.598828e+02])
# Attributes:
#     cartesian_axis:  X
#     long_name:       T-cell longitude
#     units:           degrees_E, 'lon': <xarray.Variable (grid_yt: 1536, grid_xt: 3072)> Size: 38MB
# [4718592 values with dtype=float64]
# Attributes:
#     long_name:  T-cell longitude
#     units:      degrees_E, 'grid_yt': <xarray.IndexVariable 'grid_yt' (grid_yt: 1536)> Size: 12kB
# array([ 89.910325,  89.794157,  89.677304, ..., -89.677304, -89.794157,
#        -89.910325])
# Attributes:
#     cartesian_axis:  Y
#     long_name:       T-cell latiitude
#     units:           degrees_N, 'lat': <xarray.Variable (grid_yt: 1536, grid_xt: 3072)> Size: 38MB
# [4718592 values with dtype=float64]
# Attributes:
#     long_name:  T-cell latitude
# ...

# %%
print(ds.dims)
# Out:
# FrozenMappingWarningOnValuesAccess({'grid_xt': 3072, 'grid_yt': 1536, 'time': 1})

# %%
print(ds.attrs)
# Out:
# {'fhzero': np.int32(6), 'ncld': np.int32(5), 'nsoil': np.int32(4), 'imp_physics': np.int32(11), 'dtp': np.float32(150.0), 'source': 'FV3GFS', 'grid': 'gaussian', 'im': np.int32(3072), 'jm': np.int32(1536)}

# %%
print(ds.coords)
# Out:
# Coordinates:
#   * grid_xt  (grid_xt) float64 25kB 0.0 0.1172 0.2344 ... 359.6 359.8 359.9
#   * grid_yt  (grid_yt) float64 12kB 89.91 89.79 89.68 ... -89.68 -89.79 -89.91
#   * time     (time) object 8B 2021-03-24 13:00:00

# %%
print(ds.grid_xt.values )
# Out:
# [0.00000000e+00 1.17187500e-01 2.34375000e-01 ... 3.59648438e+02
#  3.59765625e+02 3.59882812e+02]

# %%
df_xt = pd.DataFrame(ds.grid_xt.values, columns=['grid_xt'])
df_yt = pd.DataFrame(ds.grid_yt.values, columns=['grid_yt'])

# %%
ds_calif = ds.where((ds.lat >= 32) & (ds.lat <= 48) &
                     (ds.lon >= 114) & (ds.lon <= 125), drop=True)

# %%
df_calif = ds_calif.to_dataframe()

# %%
pd.set_option('display.max_columns', None)  # Show all columns

# %%
df_calif.head(10).T
# Out:
# grid_yt             47.972662                                          \
# grid_xt            114.023438          114.140625          114.257812
# time      2021-03-24 13:00:00 2021-03-24 13:00:00 2021-03-24 13:00:00
# lon                114.023438          114.140625          114.257812
# lat                 47.972662           47.972662           47.972662
# acond                0.014405            0.017933            0.017354
# albdo_ave            0.000000            0.000000            0.000000
# alnsf                0.303615            0.300707            0.300707
# ...                       ...                 ...                 ...
# xu                   0.000000            0.000000            0.000000
# xv                   0.000000            0.000000            0.000000
# xz                  30.000000           30.000000           30.000000
# xzts                 0.000000            0.000000            0.000000
# ...

# %%
df_calif.to_csv('calif_data.csv', index=False)

# Download to your computer
from google.colab import files
files.download('calif_data.csv')
